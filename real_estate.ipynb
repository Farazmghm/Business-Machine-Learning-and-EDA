# %% [markdown]
# <a href="https://colab.research.google.com/github/Farazmghm/Business-Machine-Learning-and-EDA/blob/main/real_estate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1 style="text-align: center;">Real estate project Analysis and Prediction from Utah</h1>

# %% [markdown]
# ###project contents
# 1.  [introduction](#1)
#    * 1.1 [Column Descriptors](#2)
#    * 1.2 [ joining to Drive](#3)
# 2. [First organization](#4)
#
#    * 2.1  [Require library of Python](#5)
#    * 2.2 [Loading Dataset](#6)
# 3. [initial Analysis](#7)
#    * 3.1  [Exploration](#8)
#       * 3.1.1 [ output of Exploration](#9)
#
# 4. [preparation for Data Analysis](#10)
#
#    * 4.1 [Examining Missing Values](#11)
#    * 4.2 [recognizing unique values](#12)
#    * 4.3 [output of unique values](#13)
#    * 4.4 [sepate nemuric, categoral and time series variables](#14)
#    * 4.5 [examining statistic variables](#15)
#
# 5. [Exploritory Data Analysis(EDA)](#16)
#
#    * 5.1 [Uni-variate Analysis](#17)

# %% [markdown]
# ## introduction <a id=1></a>
# This dataset contains real estate listings from Utah, comprising 4,440 entries and 14 columns. The data includes various attributes of properties such as type, description, year built, number of bedrooms and bathrooms, garage spaces, lot size, square footage, stories, listing price, and the date the property was last sold. The data was ethically mined from Realtor.com using an API provided by Apify.

# %% [markdown]
# ##Column Descriptors <a id=2></a>

# %% [markdown]
# **type**: Type of property (e.g., single_family, land)
#
# **text**: Description of the property
#
# **year_built**: Year the property was built
#
# **beds**: Number of bedrooms
#
# **baths**: Total number of bathrooms
#
# **baths_full**: Number of full bathrooms
#
# **baths_half**: Number of half bathrooms
#
# **garage**: Number of garage spaces
#
# **lot_sqft**: Lot size in square feet
#
# **sqft**: Property size in square feet
#
# **stories**: Number of stories
#
# **lastSoldOn**: Date the property was last sold
#
# **listPrice**: Listing price of the property
#
# **status**: Current status of the property (e.g., for_sale)

# %% [markdown]
# #### 1.2 joining to Drive <a id= 3 ></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. First organization <a id=6></a>

# %% [markdown]
# #### 2.1 Require library of Python <a  id= 4 ></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### 2.2 Loading Dataset <a  id= 5></a>

# %%
df=pd.read_csv("/content/drive/MyDrive/real_estate_utah.csv")
df
# Out:
#                type                                               text  \
# 0     single_family  Escape to tranquility with this off-grid, unfi...
# 1     single_family  Beautiful home in the desirable Oak Hills and ...
# 2     single_family  Welcome to your new home, nestled in the heart...
# 3     single_family  Investment Opportunity. House needs some work ...
# 4              land  Deer Springs Ranch is an 8000 Ac Ranch in an H...
# ...             ...                                                ...
# 4435  single_family  New, move-in ready 3-bed 2-bath home by Zions ...
# 4436  single_family  Located in the new elite community of The Mant...
# 4437  single_family  Beautiful Maeser location, 3 bedroom, 2 bath h...
# 4438  single_family  NEW PRICE! Best Value on the Market! Quick Mov...
# 4439  single_family  Welcome to this beautiful custom built home th...
#
#       year_built  beds  baths  baths_full  baths_half  garage  lot_sqft  \
# ...

# %% [markdown]
# ## 3. initial Analysis <a id=7></a>

# %% [markdown]
# #### 3.1 Exploration <a id= 8> </a>

# %%
df.head(10)
df.tail(10)
df.nunique()
df.columns
df.dtypes
df.shape
df.describe()
df.info()
df.value_counts().to_list()
df['beds']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4440 entries, 0 to 4439
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   type        4440 non-null   object
#  1   text        4440 non-null   object
#  2   year_built  4440 non-null   float64
#  3   beds        4440 non-null   float64
#  4   baths       4440 non-null   float64
#  5   baths_full  4440 non-null   float64
#  6   baths_half  4440 non-null   float64
#  7   garage      4440 non-null   float64
#  8   lot_sqft    4440 non-null   float64
#  9   sqft        4440 non-null   float64
#  10  stories     4440 non-null   float64
#  11  lastSoldOn  4440 non-null   object
#  12  listPrice   4440 non-null   float64
#  13  status      4440 non-null   object
# dtypes: float64(10), object(4)
# memory usage: 485.8+ KB

# %% [markdown]
# #### 3.1.1  output of Exploration <a id=10></a>
# * the Dataset consist of 4440 row and 14 columns
# * the most type of variable is numeric(float)
# * according to first impression there are not missing values(Nan) in dataset

# %% [markdown]
# ### 4. preparation for Data Analysis <a id = 11 > </a>

# %% [markdown]
# #### 4.1 Examining Missing Values <a id = 12></a>

# %%
number_miss=[]
for i in df.columns:
  x=df[i].isnull().sum()
  number_miss.append(x)

pd.DataFrame(number_miss, index=df.columns,columns=['Total of Missing Values'])
# Out:
#             Total of Missing Values
# type                              0
# text                              0
# year_built                        0
# beds                              0
# baths                             0
# baths_full                        0
# baths_half                        0
# garage                            0
# lot_sqft                          0
# sqft                              0
# stories                           0
# lastSoldOn                        0
# listPrice                         0
# status                            0

# %%
import missingno
missingno.bar(df,color='b')
# Out:
# <Axes: >

# %% [markdown]
# #### 4.2 Recognizing unique values <a id=12></a>

# %%
df.nunique()
# Out:
# type            11
# text          3991
# year_built     140
# beds            12
# baths           16
# baths_full      14
# baths_half       5
# garage          16
# lot_sqft       554
# sqft          2176
# stories          4
# lastSoldOn    1250
# listPrice     1667
# status           2
# dtype: int64

# %%
df['beds'].value_counts().to_frame()
# Out:
#       count
# beds
# 4.0    1725
# 3.0    1311
# 5.0     571
# 2.0     310
# 6.0     302
# 7.0      94
# 1.0      77
# 8.0      34
# 9.0      11
# 11.0      3
# 19.0      1
# 14.0      1

# %%
unique_types = []

for i in df["type"]:
    if i not in unique_types:
        unique_types.append(i)

pd.DataFrame(unique_types,columns=['Unique Values'])
# Out:
#                   Unique Values
# 0                 single_family
# 1                          land
# 2                        mobile
# 3                        condos
# 4                     townhomes
# 5   condo_townhome_rowhome_coop
# 6                         other
# 7                          farm
# 8                condo_townhome
# 9                     townhouse
# 10                        condo

# %%
unique_types = []

for i in df["status"]:
    if i not in unique_types:
        unique_types.append(i)
pd.DataFrame(unique_types,columns=['Unique Values'])
# Out:
#     Unique Values
# 0        for_sale
# 1  ready_to_build

# %% [markdown]
# ### 4.3 output of unique values <a id=13 ></a>
# * according to out put of unique values as numerical and categorical variables and time series
# * **numerical variables**: 'beds', 'baths', 'baths_full',
#        'baths_half', 'garage', 'lot_sqft', 'sqft'
# * **categorical variables**: 'type', 'text','stories','status',
# 'listPrice'
# * time series:'year_built','lastSoldOn'
# * in this section i seprate three groups in three diffrent lists

# %% [markdown]
# ### 4.4 sepate nemuric, categoral and time series variables <a id=14></aa>

# %%
new_columns=['type', 'text', 'year_built', 'beds', 'baths', 'baths_full',
       'baths_half', 'garage', 'lot_sqft', 'sqft', 'storage', 'lastSoldOn',
       'target', 'status']

# %%
df.columns=new_columns

# %%
nemuric_var=[ 'beds', 'baths', 'baths_full','baths_half', 'garage', 'lot_sqft', 'sqft','storage','target']
categor_var=['type', 'text','status']
time_ser=['year_built','lastSoldOn']

# %% [markdown]
# ### 4.5  examining statistic variables <a id=15></a>

# %%
df[nemuric_var].describe()
# Out:
#               beds        baths   baths_full   baths_half       garage  \
# count  4440.000000  4440.000000  4440.000000  4440.000000  4440.000000
# mean      3.894595     2.454730     2.238964     1.025000     2.334234
# std       1.265647     1.789238     1.165071     0.194672     1.024810
# min       1.000000     0.000000     1.000000     1.000000     0.000000
# 25%       3.000000     2.000000     2.000000     1.000000     2.000000
# 50%       4.000000     3.000000     2.000000     1.000000     2.000000
# 75%       4.000000     3.000000     3.000000     1.000000     2.000000
# max      19.000000    45.000000    45.000000     6.000000    20.000000
#
#            lot_sqft          sqft      storage        target
# count  4.440000e+03   4440.000000  4440.000000  4.440000e+03
# mean   5.525239e+05   2712.318243     1.999775  7.966044e+05
# std    1.134471e+07   1553.676432     0.629134  1.731703e+06
# min    4.360000e+02      0.000000     1.000000  0.000000e+00
# ...

# %% [markdown]
# ## 5. Exploritory Data Analysis(EDA)

# %%
fig, ax = plt.subplots(figsize=(12, 8))
sns.histplot(df['beds'], bins=10, kde=True, ax=ax)
mean_value = df['beds'].mean()
ax.axvline(mean_value, color='r', linestyle='--', label=f'Mean: {mean_value:.2f}')
ax.set_xlabel('Number of Beds')
ax.set_ylabel('Density')
ax.set_title('Distribution of Number of Beds')
ax.legend()
plt.show()

# %% [markdown]
# **analysis of beds values according to describe method()**
# * the value of the "beds" variable is 1. the maximum value is 19.
#  according to these two value midpoint is 10.
# * the central average is 22.5
# * there is right skew that is much
# * when we examine the quartiles ,the 25%,50%,75% bettween min and max values

# %%
fig, ax = plt.subplots(figsize=(12, 8))
sns.histplot(df['baths'], bins=10, kde=True, ax=ax)
mean_value = df['baths'].mean()
ax.axvline(mean_value, color='r', linestyle='--', label=f'Mean: {mean_value:.2f}')
ax.set_xlabel('Number of baths')
ax.set_ylabel('Density')
ax.set_title('Distribution of Number of baths')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 8))
sns.histplot(df['baths_full'], bins=10, kde=True, ax=ax)
mean_value = df['baths_full'].mean()
ax.axvline(mean_value, color='r', linestyle='--', label=f'Mean: {mean_value:.2f}')
ax.set_xlabel('Number of baths_full')
ax.set_ylabel('Density')
ax.set_title('Distribution of Number of baths_full')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 8))
sns.histplot(df['baths_half'], bins=10, kde=True, ax=ax)
mean_value = df['baths_half'].mean()
ax.axvline(mean_value, color='r', linestyle='--', label=f'Mean: {mean_value:.2f}')
ax.set_xlabel('Number of baths_half')
ax.set_ylabel('Density')
ax.set_title('Distribution of Number of baths_half')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 8))
sns.histplot(df['garage'], bins=10, kde=True, ax=ax)
mean_value = df['garage'].mean()
ax.axvline(mean_value, color='r', linestyle='--', label=f'Mean: {mean_value:.2f}')
ax.set_xlabel('Number of garage')
ax.set_ylabel('Density')
ax.set_title('Distribution of Number of garage')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 8))
sns.histplot(df['lot_sqft'], bins=10, kde=True, ax=ax)
mean_value = df['lot_sqft'].mean()
ax.axvline(mean_value, color='r', linestyle='--', label=f'Mean: {mean_value:.2f}')
ax.set_xlabel('Number of lot_sqft')
ax.set_ylabel('Density')
ax.set_title('Distribution of Number of lot_sqft')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 8))
sns.histplot(df['sqft'], bins=10, kde=True, ax=ax)
mean_value = df['sqft'].mean()
ax.axvline(mean_value, color='r', linestyle='--', label=f'Mean: {mean_value:.2f}')
ax.set_xlabel('Number of sqft')
ax.set_ylabel('Density')
ax.set_title('Distribution of Number of sqft')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 8))
sns.histplot(df['storage'], bins=10, kde=True, ax=ax)
mean_value = df['storage'].mean()
ax.axvline(mean_value, color='r', linestyle='--', label=f'Mean: {mean_value:.2f}')
ax.set_xlabel('Number of storage')
ax.set_ylabel('Density')
ax.set_title('Distribution of Number of storage')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 8))
sns.histplot(df['target'], bins=10, kde=True, ax=ax)
mean_value = df['target'].mean()
ax.axvline(mean_value, color='r', linestyle='--', label=f'Mean: {mean_value:.2f}')
ax.set_xlabel('Number of target')
ax.set_ylabel('Density')
ax.set_title('Distribution of Number of target')
ax.legend()
plt.show()

# %%
m=np.median([1,19])
print(m)
# Out:
# 10.0
